# %%
from run import gcn
# Out:
# train_ratio: 0.03
# label_distribution: [('0', 20), ('1', 6), ('2', 8), ('3', 11), ('4', 10), ('5', 8), ('6', 3)]
# balance_num: 20
# (2211, 9679) (2211, 2211) (2211, 7) (66,) (221,)
# Epoch: 0001 train_loss= 2.24372 train_acc= 0.18182 val_acc= 0.28507 val_auc= 0.64208 time= 0.24936
# train_accuracy_per_classes:{3: 0.09, 0: 0.3, 6: 0.0, 2: 0.12, 5: 0.5, 1: 0.0, 4: 0.0}
# val_accuracy_per_classes:{0: 0.83, 1: 0.0, 2: 0.0, 3: 0.37, 6: 0.0, 5: 0.09, 4: 0.04}
# Epoch: 0002 train_loss= 2.17517 train_acc= 0.45455 val_acc= 0.31674 val_auc= 0.66050 time= 0.39996
# train_accuracy_per_classes:{3: 0.64, 0: 0.8, 6: 0.0, 2: 0.25, 5: 0.38, 1: 0.0, 4: 0.2}
# val_accuracy_per_classes:{0: 0.95, 1: 0.0, 2: 0.0, 3: 0.4, 6: 0.0, 5: 0.03, 4: 0.07}
# Epoch: 0003 train_loss= 2.11646 train_acc= 0.39394 val_acc= 0.29864 val_auc= 0.65413 time= 0.54158
# train_accuracy_per_classes:{3: 0.45, 0: 0.85, 6: 0.0, 2: 0.12, 5: 0.0, 1: 0.0, 4: 0.3}
# ...
